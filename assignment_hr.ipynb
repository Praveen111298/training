# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
re=pd.read_csv("Z:\FA1\DataSets\HR_comma_sep.csv")
re 
d=re.groupby(['salary','department']).count()['average_montly_hours'].unstack()

d
# Out:
# department   IT  RandD  accounting   hr  management  marketing  product_mng  \
# salary
# high         83     51          74   45         225         80           68
# low         609    364         358  335         180        402          451
# medium      535    372         335  359         225        376          383
#
# department  sales  support  technical
# salary
# high          269      141        201
# low          2099     1146       1372
# medium       1772      942       1147

# %%
sam=re.sample(500)
sam
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 8212                 0.99             0.50               5
# 5276                 0.86             0.81               4
# 14236                0.89             0.92               5
# 1264                 0.86             0.98               4
# 1083                 0.83             0.94               4
# 12201                0.39             0.50               2
# 3545                 0.80             0.70               6
# 6292                 0.20             0.56               3
# 8877                 0.86             0.68               5
# 3304                 0.80             0.54               5
# 4974                 0.14             0.81               4
# 9617                 0.80             0.65               3
# 8240                 0.76             0.70               5
# 1337                 0.41             0.56               2
# 5630                 0.40             0.36               4
# ...

# %%
from pandas.core.reshape.reshape import unstack
fig, ax = plt.subplots(figsize=(15,7),tight_layout=True)
re.groupby(['salary','department']).count()['average_montly_hours'].unstack().plot(ax=ax)
plt.xlabel("types of salaries")
plt.ylabel("count(salaries)")
# Out:
# Text(0, 0.5, 'count(salaries)')

# %%
d.plot.bar()

plt.show()

# %%
df =re.groupby(['department'])['satisfaction_level'].mean()

df.plot(kind="bar")
plt.show()

# %%
c=re.groupby(["left","department","salary"]).count()["number_project"].unstack()
c
# Out:
# salary            high   low  medium
# left department
# 0    IT             79   437     438
#      RandD          47   309     310
#      accounting     69   259     235
#      hr             39   243     242
#      management    224   121     194
#      marketing      71   276     308
#      product_mng    62   346     296
#      sales         255  1402    1469
#      support       133   757     784
#      technical     176   994     853
# 1    IT              4   172      97
#      RandD           4    55      62
#      accounting      5    99     100
#      hr              6    92     117
#      management      1    59      31
#      marketing       9   126      68
#      product_mng     6   105      87
#      sales          14   697     303
#      support         8   389     158
#      technical      25   378     294

# %%
c.plot.bar()
plt.show()

# %%
fun=re.groupby(["left","number_project","salary"]).count()["average_montly_hours"].unstack()
fun
# Out:
# salary               high   low  medium
# left number_project
# 0    2                 94   378     349
#      3                405  1754    1824
#      4                366  1838    1752
#      5                230   946     973
#      6                 60   228     231
# 1    2                 46   966     555
#      3                  3    37      32
#      4                  2   249     158
#      5                 15   371     226
#      6                 13   405     237
#      7                  3   144     109

# %%
fun.plot.bar()
plt.show()

# %%
test=re.groupby(["left","number_project","promotion_last_5years","salary"]).count()["average_montly_hours"].unstack()
test
# Out:
# salary                                      high     low  medium
# left number_project promotion_last_5years
# 0    2              0                       87.0   374.0   335.0
#                     1                        7.0     4.0    14.0
#      3              0                      380.0  1729.0  1779.0
#                     1                       25.0    25.0    45.0
#      4              0                      343.0  1820.0  1680.0
#                     1                       23.0    18.0    72.0
#      5              0                      217.0   942.0   940.0
#                     1                       13.0     4.0    33.0
#      6              0                       56.0   227.0   219.0
#                     1                        4.0     1.0    12.0
# 1    2              0                       46.0   958.0   551.0
#                     1                        NaN     8.0     4.0
#      3              0                        3.0    37.0    32.0
# ...

# %%
test.plot.bar()
plt.show()

# %%
test1=re.groupby(["left","Work_accident"]).count()["average_montly_hours"].unstack()
test1
# Out:
# Work_accident     0     1
# left
# 0              9428  2000
# 1              3402   169

# %%
test1[1].plot(kind="pie")
plt.show()

# %%
test2=re.groupby(["left","Work_accident","promotion_last_5years","department"]).count()["average_montly_hours"].unstack()
test2
# Out:
# department                                   IT  RandD  accounting     hr  \
# left Work_accident promotion_last_5years
# 0    0             0                      799.0  521.0       463.0  432.0
#                    1                        NaN   21.0        13.0   10.0
#      1             0                      155.0  118.0        86.0   77.0
#                    1                        NaN    6.0         1.0    5.0
# 1    0             0                      261.0  111.0       195.0  208.0
#                    1                        3.0    NaN         NaN    NaN
#      1             0                        9.0   10.0         9.0    7.0
#                    1                        NaN    NaN         NaN    NaN
#
# department                                management  marketing  product_mng  \
# left Work_accident promotion_last_5years
# 0    0             0                           392.0      493.0        581.0
# ...

# %%
test2.plot(kind="bar",figsize=(10,7))
plt.show()
