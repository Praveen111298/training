# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression

# %%
cars=pd.read_csv("Z:\FA1\DataSets\Cars93.csv")
cars.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags      ...       Passengers Length  \
# 0        25           31                None      ...                5    177
# 1        18           25  Driver & Passenger      ...                5    195
# 2        20           26         Driver only      ...                5    180
# 3        19           26  Driver & Passenger      ...                6    193
# 4        22           30         Driver only      ...                4    186
#
# ...

# %%
cars.isnull().sum()
# Out:
# Unnamed: 0             0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags                0
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
cars["Luggage.room"].mean()
# Out:
# 13.890243902439025

# %%
cars["Luggage.room"].fillna(cars["Luggage.room"].mean(),inplace=True)

# %%
cars["Luggage.room"].isnull().sum()
# Out:
# 0

# %%
cars["Rear.seat.room"].fillna(cars["Rear.seat.room"].mean(),inplace=True)
cars["Rear.seat.room"].isnull().sum()
# Out:
# 0

# %%
cars.drop(["Manufacturer","Model","Type","AirBags","Turn.circle","Passengers","Origin","Make"],axis=1,inplace=True)

# %%
cars.head()
# Out:
#    Unnamed: 0  Min.Price  Price  Max.Price  MPG.city  MPG.highway DriveTrain  \
# 0           1       12.9   15.9       18.8        25           31      Front
# 1           2       29.2   33.9       38.7        18           25      Front
# 2           3       25.9   29.1       32.3        20           26      Front
# 3           4       30.8   37.7       44.6        19           26      Front
# 4           5       23.7   30.0       36.2        22           30       Rear
#
#   Cylinders  EngineSize  Horsepower   RPM  Rev.per.mile Man.trans.avail  \
# 0         4         1.8         140  6300          2890             Yes
# 1         6         3.2         200  5500          2335             Yes
# 2         6         2.8         172  5500          2280             Yes
# 3         6         2.8         172  5500          2535             Yes
# 4         4         3.5         208  5700          2545             Yes
#
# ...

# %%
cars.drop(["DriveTrain","Cylinders","Man.trans.avail","Luggage.room","Rear.seat.room"],axis=1,inplace=True)
cars.head(30)
# Out:
#     Unnamed: 0  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 0            1       12.9   15.9       18.8        25           31
# 1            2       29.2   33.9       38.7        18           25
# 2            3       25.9   29.1       32.3        20           26
# 3            4       30.8   37.7       44.6        19           26
# 4            5       23.7   30.0       36.2        22           30
# 5            6       14.2   15.7       17.3        22           31
# 6            7       19.9   20.8       21.7        19           28
# 7            8       22.6   23.7       24.9        16           25
# 8            9       26.3   26.3       26.3        19           27
# 9           10       33.0   34.7       36.3        16           25
# 10          11       37.5   40.1       42.7        16           25
# 11          12        8.5   13.4       18.3        25           36
# 12          13       11.4   11.4       11.4        25           34
# ...

# %%
cars.head(30)
# Out:
#     Unnamed: 0  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 0            1       12.9   15.9       18.8        25           31
# 1            2       29.2   33.9       38.7        18           25
# 2            3       25.9   29.1       32.3        20           26
# 3            4       30.8   37.7       44.6        19           26
# 4            5       23.7   30.0       36.2        22           30
# 5            6       14.2   15.7       17.3        22           31
# 6            7       19.9   20.8       21.7        19           28
# 7            8       22.6   23.7       24.9        16           25
# 8            9       26.3   26.3       26.3        19           27
# 9           10       33.0   34.7       36.3        16           25
# 10          11       37.5   40.1       42.7        16           25
# 11          12        8.5   13.4       18.3        25           36
# 12          13       11.4   11.4       11.4        25           34
# ...

# %%
cars.tail()
# Out:
#     Unnamed: 0  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 88          89       16.6   19.7       22.7        17           21
# 89          90       17.6   20.0       22.4        21           30
# 90          91       22.9   23.3       23.7        18           25
# 91          92       21.8   22.7       23.5        21           28
# 92          93       24.8   26.7       28.5        20           28
#
#     EngineSize  Horsepower   RPM  Rev.per.mile  Fuel.tank.capacity  Length  \
# 88         2.5         109  4500          2915                21.1     187
# 89         2.0         134  5800          2685                18.5     180
# 90         2.8         178  5800          2385                18.5     159
# 91         2.3         114  5400          2215                15.8     190
# 92         2.4         168  6200          2310                19.3     184
#
#     Wheelbase  Width  Weight
# 88        115     72    3960
# 89        103     67    2985
# ...

# %%
cars.columns
# Out:
# Index(['Unnamed: 0', 'Min.Price', 'Price', 'Max.Price', 'MPG.city',
#        'MPG.highway', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Fuel.tank.capacity', 'Length', 'Wheelbase', 'Width', 'Weight'],
#       dtype='object')

# %%
cars.corr()
# Out:
#                     Unnamed: 0  Min.Price     Price  Max.Price  MPG.city  \
# Unnamed: 0            1.000000  -0.144463 -0.137277  -0.126567  0.161808
# Min.Price            -0.144463   1.000000  0.970601   0.906756 -0.622875
# Price                -0.137277   0.970601  1.000000   0.981580 -0.594562
# Max.Price            -0.126567   0.906756  0.981580   1.000000 -0.547811
# MPG.city              0.161808  -0.622875 -0.594562  -0.547811  1.000000
# MPG.highway           0.137317  -0.579966 -0.560680  -0.522561  0.943936
# EngineSize           -0.338286   0.645488  0.597425   0.535012 -0.710003
# Horsepower           -0.233012   0.802444  0.788218   0.744445 -0.672636
# RPM                   0.167772  -0.042598 -0.004955   0.025015  0.363045
# Rev.per.mile          0.226389  -0.470395 -0.426395  -0.374024  0.695857
# Fuel.tank.capacity   -0.179034   0.635369  0.619480   0.581294 -0.813144
# Length               -0.277911   0.553859  0.503628   0.442933 -0.666239
# ...

# %%
x=cars
y=cars["Price"]

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model.score(x,y)
# Out:
# 1.0

# %%
cars.corr().max()
# Out:
# Unnamed: 0            1.0
# Min.Price             1.0
# Price                 1.0
# Max.Price             1.0
# MPG.city              1.0
# MPG.highway           1.0
# EngineSize            1.0
# Horsepower            1.0
# RPM                   1.0
# Rev.per.mile          1.0
# Fuel.tank.capacity    1.0
# Length                1.0
# Wheelbase             1.0
# Width                 1.0
# Weight                1.0
# dtype: float64
